# %% [markdown]
# ## Operator List

# %%
# Int List with Int list 

a = [10,15,22,41]
b = [10,11,20,30]

print(a+b) #Getting output [10, 15, 22, 41, 12, 11, 20, 30]

# print(a-b) TypeError:- unsupported operand type(s) for -: 'list' and 'list'

# print(a*b) TypeError: can't multiply sequence by non-int of type 'list'

# print(a/b) TypeError: unsupported operand type(s) for /: 'list' and 'list'

# print(a//b)TypeError: unsupported operand type(s) for //: 'list' and 'list'

# print(a%b) TypeError: unsupported operand type(s) for %: 'list' and 'list'

# print(a**b)TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'list'

# print(a>b) False because python compare only (10>12) not see other elements

# print(a<b) True because python compare only (10<12) not see other elements

# print(a>=b) True first element same hai 2nd element 15>=11 hai isliye True huva hai.

# print(a<=b) False first element same hai 2nd element 15<=11 hai isliye True huva hai.

# print(a==b) False beacause == mai a == b hona chahiye 1 bhi element dusare list se alag ho gaya to false hoga

# print(a!=b) True because a list ke elements b list ke equal nahi hai.
# Out:
# [10, 15, 22, 41, 10, 11, 20, 30]
# False

# %%
# List with Int

c = [5,8,2,6]
# print(c+5) TypeError: can only concatenate list (not "int") to list
# print(c-5) TypeError: unsupported operand type(s) for -: 'list' and 'int'
# print(c*3) [5, 8, 2, 6, 5, 8, 2, 6, 5, 8, 2, 6]
# print(c/3) TypeError: unsupported operand type(s) for /: 'list' and 'int'
# print(c//3)TypeError: unsupported operand type(s) for //: 'list' and 'int'
# print(c>4) TypeError: '>' not supported between instances of 'list' and 'int'
# print(c<4) TypeError: '<' not supported between instances of 'list' and 'int'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 10
#       6 # print(c*3) [5, 8, 2, 6, 5, 8, 2, 6, 5, 8, 2, 6]
#       7 # print(c/3) TypeError: unsupported operand type(s) for /: 'list' and 'int'
#       8 # print(c//3)TypeError: unsupported operand type(s) for //: 'list' and 'int'
#       9 # print(c>4) TypeError: '>' not supported between instances of 'list' and 'int'
# ---> 10 print(c<4)
#      11
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
# List of string
a =["apple", "Mango", "Banana", "Cherry"]
b =["apple", "Water", "Pineapple", "Pear"]

# print(a+b) ['apple', 'Mango', 'Banana', 'Cherry', 'apple', 'Water', 'Pineapple', 'Pear']
# print(a-b) TypeError: unsupported operand type(s) for -: 'list' and 'list'
# print(a*b) TypeError: can't multiply sequence by non-int of type 'list'
# print(a/b) TypeError: unsupported operand type(s) for /: 'list' and 'list'
# print(a//b)TypeError: unsupported operand type(s) for //: 'list' and 'list'
# print(a==b)False
# print(a!=b)True

"""print(a>b)False because 1st element is same in both list here compare 2nd elements in aplhabetically mango>water 
(alphabets 'm' pahale aata hai or 'w' baad mai. )aplhabet mai jo pahale aata hai wo '<' or jo baad mai aata hai wo > grater than.
"""
# print(a<b) True (alphabet mai 'm'chota hai 'w' se 'a<b= true)
# print(a>=b) False
# print(a<=b) True
# Out:
# True

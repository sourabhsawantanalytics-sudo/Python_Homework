# %% [markdown]
# ## Explore String Methods Types

# %%
line="Explore string method.pdf"
count=line.index('.')
print(count) 
name=line[ : count]
print(name)
extension=line[count+1: ]
print("extension")
# Out:
# 21
# Explore string method
# extension

# %%
line= "Explore string method.pdf"
count=line.index('.')
print("Count =", count) 

name =line[ : count]
print("Name =", name.lower())

extension=line[count+1: ]
print("Extension =",  extension.upper())
# Out:
# Extension = PDF
# Count = 21
# Name = explore string method

# %%
website="www.google.com"
count = website.index('.')
print(count)
print(website.find('o'))
print(website.index('l'))
print(website.count('o'))
print(website.upper())
print(website.title())
print(website.lower())
print(website.replace("google", "facebook"))
print(website.islower())
print(website.istitle())
print(website.isspace())
print(website.isdigit())
# Out:
# 3
# 5
# 8
# 3
# WWW.GOOGLE.COM
# Www.Google.Com
# www.google.com
# www.facebook.com
# True
# False
# False
# False

# %% [markdown]
# Operators
# Relational/Comparision Oprators
# >, <, >=, <=

# %%
x = 35
y = 32
# print(x > y)
print(x < y)
# Out:
# False

# %%
Ram = 28
Jhon = 28
result1 = (Ram == Jhon)
result2 = (Ram != Jhon)
print(result1, result2)
# Out:
# True False

# %%
Ajay = 28
Mohan = 28
# Who will pay the bill?
if Ajay > Mohan:
    print("Ajay will pay the bill")

elif Ajay == Mohan:
    print("Both will pay the bill")

else:
    print("Mohan will pay the bill")

print("Closed the program")
# Out:
# Both will pay the bill
# Closed the program

# %% [markdown]
# Logical Oprator
# AND

# %%
a = True
b = False
print( a and b)
# Out:
# False

# %%
a = False
b = True
print( a and b)
# Out:
# False

# %%
a = True
b = True
print( a and b)
# Out:
# True

# %%
a = False
b = False
print(a and b)
# Out:
# False

# %% [markdown]
# Logical OR Oprator

# %%
a = True
b = False
print( a or b)
# Out:
# True

# %%
a = False
b = True
print( a or b)
# Out:
# True

# %%
a = True
b = True
print( a or b)
# Out:
# True

# %%
a = False
b = False
print( a or b)
# Out:
# False

# %%
a = True
b = False
c = True
print( a and b and c)
print( a and b or c)
print( a or b and c)
print( a or b or c)
# Out:
# False
# True
# True
# True

# %%
c1 = "Samsung"
c2 = "Apple"
c3 = "Oppo"

if not(c1 == "oppo" or c1 =="Apple"):
    print("Koi bhi chalega")
    print("Stop the program")
# Out:
# Koi bhi chalega
# Stop the program

# %% [markdown]
# NOT : Inversion oprator

# %%
a = False
b = True


print(not a, not b)
# Out:
# True False
